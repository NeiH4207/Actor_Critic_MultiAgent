# %%
"""
Created on Fri Nov 27 16:00:47 2020
@author: hien
"""
from __future__ import division

import logging
from src.environment import Environment
from read_input import Data
from src.model import Policy
from src.Coach import Coach
from src.utils import dotdict
import torch

# %%
log = logging.getLogger(__name__)

args = dotdict({
    'run_mode': 'train',
    'visualize': True,
    'min_size': 7,
    'max_size': 7,
    'n_games': 1,
    'n_maps': 1000,
    'show_screen': False,
    'replay_memory_size': 10000,
    'initial_epsilon': 0.1,
    'final_epsilon': 1e-4,
    'dir': './Models/',
    'numIters': 1000,
    'numEps': 3,              # Number of complete self-play games to simulate during a new iteration.
    'tempThreshold': 15,        #
    'updateThreshold': 0.6,     # During arena playoff, new neural net will be accepted if threshold or more of games are won.
    'maxlenOfQueue': 10000,    # Number of game examples to train the neural networks.
    'numMCTSSims': 3,          # Number of games moves for MCTS to simulate.
    'arenaCompare': 40,         # Number of games to play during arena play to determine if new net will be accepted.
    'cpuct': 1,
    'colab_train': False,
    'colab_dir': "/content/drive/MyDrive/trainned_model/agent_mcts.pt",
    'checkpoint': './temp/',
    'load_model': False,
    'load_folder_file': ('Models','agent_mcts.pt'),
    'numItersForTrainExamplesHistory': 15,
    'saved_model': True
})

# %%
data = Data(args.min_size, args.max_size)
env = Environment(data.get_random_map(), args.show_screen, args.max_size)
model = Policy(env)
if args.load_model:
    log.info('Loading checkpoint "%s/%s"...', args.load_folder_file)
    model.load_checkpoint(args.load_folder_file[0], args.load_folder_file[1])
else:
    log.warning('Not loading a checkpoint!')
# Out:
# Not loading a checkpoint!

# %%
# log.info('Loading the Coach...')
coach = Coach(env, model, args)

# if args.load_model:
#     # log.info("Loading 'trainExamples' from file...")
#     coach.loadTrainExamples()

# log.info('Starting the learning process !')
for i in range(args.numIters):
    # bookkeeping
    log.info(f'Starting Iter #{i} ...')
    coach.learn(i)
    coach.game = Environment(data.get_random_map(), args.show_screen, args.max_size)
# Out:
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.85it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  4.03it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.68it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.57it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.49it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.46it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  5.35it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.94it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  4.82it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.78it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00,  3.63it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Training Net: 0it [00:00, ?it/s]
# Checkpoint Directory exists!
# Self Play: 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:01<00:00,  2.28it/s]
# Training Net:   0%|                                                                                                    | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_232124/1700332880.py in <module>
#      10     # bookkeeping
#      11     log.info(f'Starting Iter #{i} ...')
# ---> 12     coach.learn(i)
#      13     coach.game = Environment(data.get_random_map(), args.show_screen, args.max_size)
#
# ~/Desktop/AI/RL/Actor_Critic_MultiAgent/src/Coach.py in learn(self, iter)
#     129             trainExamples.extend(e)
#     130         shuffle(trainExamples)
# --> 131         self.nnet.train_examples(trainExamples)
#     132
#     133         # training new network, keeping a copy of the old one
#
# ~/Desktop/AI/RL/Actor_Critic_MultiAgent/src/model.py in train_examples(self, examples)
#     143                 # boards = self.env.get_states_for_step(boards)
#     144                 # agent_steps = self.env.get_agents_for_step(agent_steps)
# --> 145                 boards = torch.FloatTensor(boards.astype(np.float64)).to(self.device)
#     146                 agent_steps = torch.FloatTensor(agent_steps.astype(np.float64)).to(self.device)
#     147                 target_pis = torch.FloatTensor(np.array(pis))
#
# AttributeError: 'tuple' object has no attribute 'astype'
